# %% [markdown]
# # Question 8
# - Use nps_chat and wordlist corpus.
# - If you find a word in nps_chat but not in wordlist, it is considered an unusual word.
#   (e.g. Heyyyy, gr8, 4ever can be considered unusual words for this analysis)
# - Find out how many unusual words people speak in chat (notice: usernames should not be counted)
# - Bonus: What if I want to  count : ) , : ( all these emoticons in. (optional)

# %%
from nltk.corpus import nps_chat
from nltk.corpus import words
from nltk.corpus import stopwords
import string
import re

# %%
pun = re.compile('.*[A-Za-z].*') #Creating a list of punctuations to be removed.

# %%
chat_words=[c.lower() for c in nps_chat.words()]                          #Converting text to lower case.
fil_chat = [x for x in chat_words if x not in stopwords.words('english')] #Removing stop words.
fil_chat = [u for u in fil_chat if pun.match(u)]                          #Removing punctuations.
fil_chat = set(fil_chat)

# %%
unusual_words = [w for w in fil_chat if w not in words.words() ]    #Filtering out the unusual words.

# %%
print("The no of unusual word are:",len(unusual_words))
# Out:
# The no of unusual word are: 2617

# %%
sorted(unusual_words)
# Out:
# ['"s',
#  '#14-19teens',
#  '#40splus',
#  '#prideisland',
#  '#talkcity-20s',
#  '#talkcity_adults',
#  "'d",
#  "'ello",
#  "'ll",
#  "'m",
#  "'n'",
#  "'re",
#  "'s",
#  "'ve",
#  '( o y o )',
#  '(__i__)',
#  '*blush*',
#  '*drools*',
#  '*grins*',
#  '*hugs*',
#  '*smewchies*',
#  '*sniffs*',
#  '*spank*',
#  '*vbs*',
#  '*waves*',
#  '*wow*',
#  '-o',
#  '-s',
#  '-stay-',
#  '.(..(.vmp3 v1.7.4.).)',
#  '.(..(.vmp3 vi.p.t.)..).',
#  '.a.n.a.c.?.n.?.a.',
#  '.op.',
#  '.owner.',
#  '//www.wunderground.com/cgi-bin/findweather/getforecast?query=95953#fir',
#  '1-900-anal-sex',
#  '10th',
#  '18st',
#  '1cos',
#  '20s',
#  '2day',
#  '2nd',
#  '2pac',
#  '60s',
#  ':-o',
#  ':beer:',
#  ':blush:',
#  ':d',
#  ':love:',
#  ':o',
#  ':o *',
#  ':p',
#  ':tongue:',
#  ';p',
#  "<3's",
#  '<empty>',
#  '<perk>',
#  "='s",
#  '=d',
#  '=o',
#  '=p',
#  '\\ty',
#  'aaaaaaaaaaaaaaaaa',
#  'aaahhhh',
#  'aberdeen',
#  'abortions',
#  'abou',
#  'abourted',
#  'abs',
#  'ack',
#  'acros',
# ...

# %%
#Optional 
#only few emoticons have been checked.
#emo=[':‑)',':)',':-]',':]',':-3',':3',':->',':>','8-)','8)',':-}',':}',':o)',':c)',':^)','=]','=)','-o','-s']
emo=[':)',':(']

# %%
len([e for e in chat_words if e in emo])
# Out:
# 110
