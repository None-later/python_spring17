# %%
import requests,json,os
import re,datetime
import shutil

# %%
nyt_article_search_key = os.getenv('auth_key')
print(nyt_article_search_key)
# Out:
# 64c3ab93117a4311b15dd35ecb7cff3d

# %%
dir_path = 'Archive'                  #Relative path
os.makedirs(dir_path, exist_ok=True)

# %%
for y in range(2006,2017):
    for m in range(1,13):
        
        art_url=('http://api.nytimes.com/svc/archive/v1/'+str(y)+'/'+str(m)+'.json?api-key='+ nyt_article_search_key)
        get_request=requests.get(art_url)
        article=json.loads(get_request.text)
        for i in range(0,5000):
            try:
        
                t=article['response']['docs'][i]['pub_date']
                match = re.search(r'\d{4}-\d{2}-\d{2}', t)
                date = datetime.datetime.strptime(match.group(), '%Y-%m-%d').date()
        
                year_path = os.path.join(dir_path, str(date.year))   
                os.makedirs(year_path,exist_ok=True)
                month_path = os.path.join(year_path, date.strftime("%b"))
                os.makedirs(month_path, exist_ok=True)
    
            except IndexError:
                pass
            with open(article['response']['docs'][i]['_id'],'w')as outfile:
                json.dump(article['response']['docs'][i],outfile)
        for files in os.listdir('/Users/nithinkartha/Desktop/Masters/study materials/DAUPy/HW/python_spring17/midterm/Que 2'):
            if files.endswith('.ipynb'):
                print(date.year,date.strftime("%b"))
            else:
                try:
                    shutil.move(os.path.join('/Users/nithinkartha/Desktop/Masters/study materials/DAUPy/HW/python_spring17/midterm/Que 2',files), os.path.join(month_path,files+'.json'))
                except OSError:
                    pass
# Out:
# 2006 Jan
# 2006 Jan
# 2006 Jan
# 2006 Feb
# 2006 Feb
# 2006 Feb
# 2006 Mar
# 2006 Mar
# 2006 Mar
# 2006 Apr
# 2006 Apr
# 2006 Apr
# 2006 May
# 2006 May
# 2006 May
# 2006 Jun
# 2006 Jun
# 2006 Jun
# 2006 Jul
# 2006 Jul
# 2006 Jul
# 2006 Aug
# 2006 Aug
# 2006 Aug
# 2006 Sep
# 2006 Sep
# 2006 Sep
# 2006 Oct
# 2006 Oct
# 2006 Oct
# 2006 Nov
# 2006 Nov
# 2006 Nov
# 2006 Dec
# 2006 Dec
# 2006 Dec
# 2007 Jan
# 2007 Jan
# 2007 Jan
# 2007 Feb
# 2007 Feb
# 2007 Feb
# 2007 Mar
# 2007 Mar
# 2007 Mar
# 2007 Apr
# 2007 Apr
# 2007 Apr
# 2007 May
# 2007 May
# 2007 May
# 2007 Jun
# 2007 Jun
# 2007 Jun
# 2007 Jul
# 2007 Jul
# 2007 Jul
# 2007 Aug
# 2007 Aug
# 2007 Aug
# 2007 Sep
# 2007 Sep
# 2007 Sep
# 2007 Oct
# 2007 Oct
# 2007 Oct
# 2007 Nov
# 2007 Nov
# 2007 Nov
# 2007 Dec
# 2007 Dec
# 2007 Dec
# 2008 Jan
# 2008 Jan
# 2008 Jan
# 2008 Feb
# 2008 Feb
# 2008 Feb
# 2008 Mar
# 2008 Mar
# 2008 Mar
# 2008 Apr
# 2008 Apr
# 2008 Apr
# 2008 May
# 2008 May
# 2008 May
# 2008 Jun
# 2008 Jun
# 2008 Jun
# 2008 Jul
# 2008 Jul
# 2008 Jul
# 2008 Aug
# 2008 Aug
# 2008 Aug
# 2008 Sep
# 2008 Sep
# 2008 Sep
# 2008 Oct
# 2008 Oct
# 2008 Oct
# 2008 Nov
# 2008 Nov
# 2008 Nov
# 2008 Dec
# 2008 Dec
# 2008 Dec
# 2009 Jan
# 2009 Jan
# 2009 Jan
# 2009 Feb
# 2009 Feb
# 2009 Feb
# 2009 Mar
# 2009 Mar
# 2009 Mar
# 2009 Apr
# 2009 Apr
# 2009 Apr
# 2009 May
# 2009 May
# 2009 May
# 2009 Jun
# 2009 Jun
# 2009 Jun
# 2009 Jul
# 2009 Jul
# 2009 Jul
# 2009 Aug
# 2009 Aug
# 2009 Aug
# 2009 Sep
# 2009 Sep
# 2009 Sep
# 2009 Oct
# 2009 Oct
# 2009 Oct
# 2009 Nov
# 2009 Nov
# 2009 Nov
# 2009 Dec
# 2009 Dec
# 2009 Dec
# 2010 Jan
# 2010 Jan
# 2010 Jan
# 2010 Feb
# 2010 Feb
# 2010 Feb
# 2010 Mar
# 2010 Mar
# 2010 Mar
# 2010 Apr
# 2010 Apr
# 2010 Apr
# 2010 May
# 2010 May
# 2010 May
# 2010 Jun
# 2010 Jun
# 2010 Jun
# 2010 Jul
# 2010 Jul
# 2010 Jul
# 2010 Aug
# 2010 Aug
# 2010 Aug
# 2010 Sep
# 2010 Sep
# 2010 Sep
# 2010 Oct
# 2010 Oct
# 2010 Oct
# 2010 Nov
# 2010 Nov
# 2010 Nov
# 2010 Dec
# 2010 Dec
# 2010 Dec
# 2011 Jan
# 2011 Jan
# 2011 Jan
# 2011 Feb
# 2011 Feb
# 2011 Feb
# 2011 Mar
# 2011 Mar
# 2011 Mar
# 2011 Apr
# 2011 Apr
# 2011 Apr
# 2011 May
# 2011 May
# 2011 May
# 2011 Jun
# 2011 Jun
# 2011 Jun
# 2011 Jul
# 2011 Jul
# 2011 Jul
# 2011 Aug
# 2011 Aug
# 2011 Aug
# 2011 Sep
# 2011 Sep
# 2011 Sep
# 2011 Oct
# 2011 Oct
# 2011 Oct
# 2011 Nov
# 2011 Nov
# 2011 Nov
# 2011 Dec
# 2011 Dec
# 2011 Dec
# 2012 Jan
# 2012 Jan
# 2012 Jan
# 2012 Feb
# 2012 Feb
# 2012 Feb
# 2012 Mar
# 2012 Mar
# 2012 Mar
# 2012 Apr
# 2012 Apr
# 2012 Apr
# 2012 May
# 2012 May
# 2012 May
# 2012 Jun
# 2012 Jun
# 2012 Jun
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-4-ee018024918f> in <module>()
#       4         art_url=('http://api.nytimes.com/svc/archive/v1/'+str(y)+'/'+str(m)+'.json?api-key='+ nyt_article_search_key)
#       5         get_request=requests.get(art_url)
# ----> 6         article=json.loads(get_request.text)
#       7         for i in range(0,5000):
#       8             try:
#
# /Users/nithinkartha/anaconda/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# /Users/nithinkartha/anaconda/lib/python3.5/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /Users/nithinkartha/anaconda/lib/python3.5/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
