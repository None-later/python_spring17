# %%
from email.parser import Parser
import os,csv
import matplotlib.pyplot as mp
from datetime import datetime
import string, re
dir_path='/Users/nithinkartha/Desktop/Masters/study materials/DAUPy/HW/python_spring17/midterm/data/enron/maildir/'

# %%
mail_sub={}
thread_starter={}
for root, dirs, files in os.walk(dir_path):
    if "sent" in root:
        for f in files:
            with open(os.path.join(root,f),'r',encoding='utf-8',errors='ignore') as e:
                data=e.read()
                email=Parser().parsestr(data)
                if not 'fw:'in email["Subject"].lower():
                    if not 're:'in email["Subject"].lower():
                        if email["Subject"].lower() and not email["Subject"].lower().isspace():
                            if email["Subject"].lower() not in mail_sub:
                                mail_sub[email["Subject"].lower()]=1
                                if email["From"] not in thread_starter:
                                    thread_starter[email["From"]]=1
                                else:
                                    thread_starter[email["From"]]+=1
                            else:
                                mail_sub[email["Subject"].lower()]+=1

# %%
top100_mail_thread = {m: mail_sub[m] for m in sorted(mail_sub, key=mail_sub.get, reverse=True)[0:100]}
for x in sorted(top100_mail_thread, key=top100_mail_thread.get, reverse=True):
    print(x,top100_mail_thread[x])
# Out:
# hey 126
# var 107
# test 94
# btu weekly 81
# yo 76
# meeting 75
# congratulations 74
# gisb 66
# btu's weekly power report 63
# lunch 61
# presentation 53
# hi 49
# confidentiality agreement 47
# fyi 46
# pueblo 45
# (no subject) 40
# agreement 40
# approval for reviewer 36
# eol 36
# organizational changes 35
# master agreement 33
# your approval is requested 32
# trade 32
# boo 29
# conference call 28
# isda master agreement 28
# information 27
# northwestern 25
# draft 25
# pg&e 25
# misc 23
# hello! 23
# golf 23
# isda 23
# duke 23
# attached files 23
# mdea 23
# various 22
# info 22
# vacation 22
# 2000 ena offsite 22
# ces deals 22
# out of the office 21
# how are you? 21
# reminder 21
# vepco 21
# entouch newsletter 21
# contracts 21
# organizational announcement 20
# dinner 20
# update 20
# thank you 20
# attachment 20
# remove 20
# contact info 20
# trade confirmation 20
# happy hour 20
# fwd: 20
# ena management committee 20
# gallup 19
# out of office 19
# what's up? 19
# article 19
# organization announcement 18
# book request 18
# howdy 18
# sita 18
# ps 18
# address 18
# to_do 18
# accomplishments 18
# staff meeting 18
# reviews 18
# eol products 17
# egm business presentation 17
# abb 17
# this weekend 17
# hello 17
# time sensitive: executive impact & influence program survey 16
# final - january 2000 needs 16
# enron wholesale services legal department 16
# cgas storage 16
# invitation 16
# enrononline 16
# good morning 16
# api and api crude, distillate & unleaded stocks graphs 16
# egan storage 15
# ca 15
# master netting agreement 15
# ca development agreements 15
# new power 15
# enron mentions 15
# ca data sheet 15
# fwd: election concession & retraction parody. has good audio also. 15
# status 15
# pseg 14
# expense report 14
# a computer and internet connection for you and your family 14
# blue dog 14
# cop shock 14

# %%
x1=[]
y1=[]
top50_thread_starter = {t: thread_starter[t] for t in sorted(thread_starter, key=thread_starter.get, reverse=True)[:50]}
for x in sorted(top50_thread_starter, key=top50_thread_starter.get, reverse=True):
    x1.append(x)
    y1.append(top50_thread_starter[x])
    print(x,top50_thread_starter[x])
# Out:
# tana.jones@enron.com 1941
# sara.shackleton@enron.com 1905
# kay.mann@enron.com 1293
# jeff.dasovich@enron.com 1244
# vince.kaminski@enron.com 1181
# chris.germany@enron.com 1126
# gerald.nemec@enron.com 930
# mark.taylor@enron.com 649
# debra.perlingiere@enron.com 524
# sally.beck@enron.com 497
# elizabeth.sager@enron.com 457
# steven.kean@enron.com 429
# carol.clair@enron.com 420
# eric.bass@enron.com 396
# susan.scott@enron.com 396
# richard.sanders@enron.com 360
# david.delainey@enron.com 358
# darron.giron@enron.com 334
# drew.fossum@enron.com 307
# kate.symes@enron.com 266
# d..steffes@enron.com 241
# jeffrey.shankman@enron.com 234
# mark.haedicke@enron.com 233
# michelle.cash@enron.com 232
# chris.dorland@enron.com 222
# marie.heard@enron.com 215
# mike.grigsby@enron.com 209
# phillip.love@enron.com 206
# mike.mcconnell@enron.com 192
# dan.hyvl@enron.com 188
# bill.williams@enron.com 186
# m..forney@enron.com 179
# daren.farmer@enron.com 179
# lynn.blair@enron.com 176
# larry.campbell@enron.com 168
# barry.tycholiz@enron.com 167
# louise.kitchen@enron.com 158
# shelley.corman@enron.com 157
# mary.hain@enron.com 151
# kimberly.watson@enron.com 147
# scott.neal@enron.com 144
# cara.semperger@enron.com 129
# phillip.allen@enron.com 126
# kevin.hyatt@enron.com 123
# errol.mclaughlin@enron.com 120
# robin.rodrigue@enron.com 119
# monika.causholli@enron.com 114
# m..love@enron.com 113
# rick.buy@enron.com 110
# michelle.lokay@enron.com 105

# %%
mp.style.use('ggplot') 
mp.style.use('seaborn-poster')
mp.bar(range(len(sorted(top50_thread_starter, key=top50_thread_starter.get, reverse=True))),y1,align='center',linewidth=2,width=.75)
mp.xticks(range(len(sorted(top50_thread_starter, key=top50_thread_starter.get, reverse=True))),x1,rotation=90)

mp.ylabel('Thread Count')
mp.xlabel('Employee Name')

mp.show()
