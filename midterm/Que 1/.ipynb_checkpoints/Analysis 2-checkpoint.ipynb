# %%
from email.parser import Parser
import os,csv
import matplotlib.pyplot as mp
from datetime import datetime
import string, re
dir_path='../../midterm/data/enron/maildir/'

# %%
i=0
mail_sub={}
thread_starter={}
for root, dirs, files in os.walk(dir_path):
    if "sent" in root:
        for f in files:
            with open(os.path.join(root,f),'r',encoding='utf-8',errors='ignore') as e:
                data=e.read()
                email=Parser().parsestr(data)

                if 're:' in email["Subject"].lower() or 'fw:' in email["Subject"].lower() :
                    
                    yo=email["Subject"].lower().replace("re: ", "")
                    yo=yo.replace("re:", "")
                    yo=yo.replace("fw: ", "")
                    yo=yo.replace("fw:", "")
                    if yo and not yo.isspace():
                         
                        if yo not in mail_sub:
                            mail_sub[yo]=1
                        else:
                            mail_sub[yo]+=1
                else:
                    if email["Subject"].lower() and not email["Subject"].lower().isspace():
                         
                            
                        if email["Subject"].lower() not in mail_sub:
                            mail_sub[email["Subject"].lower()]=1
                            if email["From"] not in thread_starter:
                                thread_starter[email["From"]]=1
                            else:
                                thread_starter[email["From"]]+=1
                        elif email["Subject"].lower() in mail_sub :
                            mail_sub[email["Subject"].lower()]+=1
# Out:
# 113198

# %%
top100_mail_thread = {m: mail_sub[m] for m in sorted(mail_sub, key=mail_sub.get, reverse=True)[0:100]}
for x in sorted(top100_mail_thread, key=top100_mail_thread.get, reverse=True):
    print(x,top100_mail_thread[x])
# Out:
# lunch 270
# hey 240
# hi 198
# meeting 194
# test 185
# (no subject) 168
# congratulations 136
# vacation 134
# yo 130
# var 125
# hello 125
# resume 111
# update 106
# apb checkout 102
# happy hour 102
# gisb 101
# dinner 100
# confidentiality agreement 97
# good morning 95
# fyi 91
# thank you 89
# btu weekly 88
# organization announcement 85
# presentation 84
# question 79
# hello! 77
# golf 75
# conference call 74
# apb 72
# btu's weekly power report 70
# thanks 70
# this weekend 68
# trade 67
# organizational changes 65
# enron center garage 64
# pueblo 63
# hi! 60
# eol 60
# master agreement 59
# one more try 59
# northwestern 59
# what's up? 58
# congratulations! 56
# status 54
# reminder 52
# confidential 51
# draft 50
# agreement 50
# tonight 49
# isda 48
# saturday 48
# weekly ge conference call 47
# natsource checkout 46
# isda master agreement 46
# address 46
# how are you? 45
# organizational announcement 45
# your approval is requested 43
# stuff 43
# <no subject> 43
# misc 42
# vepco 42
# enron 41
# boo 41
# duke 40
# attached files 39
# letter agreement 39
# new power 39
# vegas 39
# ene 39
# info 38
# friday 38
# contact info 38
# ? 38
# bs 37
# visit 37
# follow-up 37
# follow up 37
# houston 36
# pg&e 36
# ps 36
# article 36
# mdea 36
# approval for reviewer 36
# information 36
# options 36
# weekend 35
# promotion 35
# opportunities at ena 35
# tfs 35
# happy birthday 34
# contracts 34
# houston visit 34
# salmon energy turbine agreement 34
# peoples 34
# greetings 33
# wireless message 33
# enrononline 33
# 2- survey/information email 33
# natsource 33

# %%
x1=[]
y1=[]
top50_thread_starter = {t: thread_starter[t] for t in sorted(thread_starter, key=thread_starter.get, reverse=True)[:50]}
for x in sorted(top50_thread_starter, key=top50_thread_starter.get, reverse=True):
    x1.append(x)
    y1.append(top50_thread_starter[x])
    print(x,top50_thread_starter[x])
# Out:
# tana.jones@enron.com 1887
# sara.shackleton@enron.com 1822
# jeff.dasovich@enron.com 1186
# vince.kaminski@enron.com 1002
# chris.germany@enron.com 903
# gerald.nemec@enron.com 889
# kay.mann@enron.com 883
# mark.taylor@enron.com 589
# debra.perlingiere@enron.com 463
# sally.beck@enron.com 435
# elizabeth.sager@enron.com 426
# carol.clair@enron.com 381
# steven.kean@enron.com 377
# richard.sanders@enron.com 325
# susan.scott@enron.com 306
# darron.giron@enron.com 302
# david.delainey@enron.com 297
# eric.bass@enron.com 297
# drew.fossum@enron.com 250
# d..steffes@enron.com 224
# michelle.cash@enron.com 217
# mark.haedicke@enron.com 213
# kate.symes@enron.com 212
# marie.heard@enron.com 207
# jeffrey.shankman@enron.com 200
# mike.grigsby@enron.com 182
# chris.dorland@enron.com 181
# dan.hyvl@enron.com 176
# m..forney@enron.com 171
# phillip.love@enron.com 168
# lynn.blair@enron.com 164
# bill.williams@enron.com 160
# larry.campbell@enron.com 156
# mike.mcconnell@enron.com 153
# daren.farmer@enron.com 153
# mary.hain@enron.com 139
# barry.tycholiz@enron.com 137
# kimberly.watson@enron.com 136
# shelley.corman@enron.com 131
# kevin.hyatt@enron.com 118
# scott.neal@enron.com 116
# cara.semperger@enron.com 113
# errol.mclaughlin@enron.com 111
# phillip.allen@enron.com 109
# monika.causholli@enron.com 101
# louise.kitchen@enron.com 101
# michelle.lokay@enron.com 100
# rick.buy@enron.com 99
# twanda.sweet@enron.com 95
# robin.rodrigue@enron.com 95

# %%
mp.style.use('ggplot') 
mp.style.use('seaborn-poster')
mp.bar(range(len(sorted(top50_thread_starter, key=top50_thread_starter.get, reverse=True))),y1,align='center',linewidth=2,width=.75)
mp.xticks(range(len(sorted(top50_thread_starter, key=top50_thread_starter.get, reverse=True))),x1,rotation=90)

mp.ylabel('Thread Count')
mp.xlabel('Employee Name')

mp.show()
